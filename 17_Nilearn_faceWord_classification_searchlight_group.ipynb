# %% [markdown]
# # Group analysis on searchlight maps from the FaceWord experiment
#
# In the FaceWord experiment, participants looked at words and faces while undergoing fMRI.
# P participantwe are presented with a word, which thewould y try to use to predict the emotionfon an upcoming emoji (happy/fearful). Their taswa is to respond wita h button press to indicate which type of emoji was presented![faceWord_img_stim_both.png](attachment:86ba8a07-fdd8-4e5a-beda-7b149364b886.png)
#
# 21 cognitive science students participated in the experiment over the course of several years (2019-202 as part of courses in cognitive neuroscience at Aarhus University3).
#
# The experiment consisted of 6 sessions with 60 WordFace trials in ea (30 positive, 30 negative)ch. Each session lasted 10 minutes.
#
# Each fMRI volume consisted of 45 slices (voxel-size: 2.53x2.53x3mm). Data was acquired with a TR=1s (1H, yielding a total of 600 images per sessionz The raw data can be found in the fMRI-data folder.
#
# All data was preprocessed using fMRIprep.).
#
# In this analysis, we have modelled the onsset foeverych positive and negative emojas an individual column in the design matrix, using the Glover HRF. The design matrix includes 22 nuisance variables and a cosine set for highpass filtering ![faceWord_decoding_design_mat.png](attachment:cf5d145b-4c9c-4443-a827-57c99315778c.png)
#
# O our aim is to see if there is a difference between the t types of emojisz
#
# To this end, we have conducted a searchlight analysis on 80% of the 360 trials. We now take the accuracy image for each participant and subject them to a 2nd level t-test.
#
# #### Tasks and questions for assignment 5 are written at the bottom of the notebook.

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# # Preamble: Activate environment
# In the first notebook, we installed a python environment. If you haven't don so, please go back to the ```01_setup_virtual_environment.ipynb``` and complete this before proceeding.
#
# If you closed/stopped the UCloud run between then and now, we will need to reactivate the environment.
#
# For this we use a bash script with a subset of the lines we used for setting up the environment
#
# The script called ```activate.sh``` This should be located in your working directory. If not, save the following in a file with this filename.
#
# ```bash
# . /work/<MY DIRECTORY NUMBER>/virt_env/bin/activate
# python -m ipykernel install --user --name=virt_env
# echo Done! Remember changing the kernel in Jupyter.
# ```
# </div>

# %%
import os
path='/work/biankas_folder/notebooks/' # Remember to change this to your own path
os.chdir(path)
# !./activate.sh
# Out:
# Installed kernelspec virt_env in /home/coder/.local/share/jupyter/kernels/virt_env
# Done! Remember changing the kernel in Jupyter.

# %%
# !./install_python_packages.sh
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imageio in /home/coder/.local/lib/python3.9/site-packages (2.33.1)
# Requirement already satisfied: pillow>=8.3.2 in /home/coder/.local/lib/python3.9/site-packages (from imageio) (9.2.0)
# Requirement already satisfied: numpy in /home/coder/.local/lib/python3.9/site-packages (from imageio) (1.23.0)
#
# [notice] A new release of pip available: 22.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in /home/coder/.local/lib/python3.9/site-packages (1.8.1)
# Requirement already satisfied: numpy<1.25.0,>=1.17.3 in /home/coder/.local/lib/python3.9/site-packages (from scipy) (1.23.0)
#
# [notice] A new release of pip available: 22.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/coder/.local/lib/python3.9/site-packages (1.23.0)
#
# [notice] A new release of pip available: 22.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib==3.7.1
#   Downloading matplotlib-3.7.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 47.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.7 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib==3.7.1) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib==3.7.1) (1.4.3)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (310 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.0/311.0 kB 5.2 MB/s eta 0:00:0000:01
# Requirement already satisfied: numpy>=1.20 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib==3.7.1) (1.23.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib==3.7.1) (4.34.1)
# Requirement already satisfied: packaging>=20.0 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib==3.7.1) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib==3.7.1) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib==3.7.1) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib==3.7.1) (3.0.9)
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: zipp>=3.1.0 in /home/coder/.local/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib==3.7.1) (3.8.0)
# Requirement already satisfied: six>=1.5 in /home/coder/.local/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib==3.7.1) (1.16.0)
# Installing collected packages: importlib-resources, contourpy, matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.5.2
#     Uninstalling matplotlib-3.5.2:
#       Successfully uninstalled matplotlib-3.5.2
# Successfully installed contourpy-1.2.0 importlib-resources-6.1.1 matplotlib-3.7.1
#
# [notice] A new release of pip available: 22.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting dicom2nifti
#   Downloading dicom2nifti-2.4.9-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /home/coder/.local/lib/python3.9/site-packages (from dicom2nifti) (1.8.1)
# Requirement already satisfied: numpy in /home/coder/.local/lib/python3.9/site-packages (from dicom2nifti) (1.23.0)
# Collecting pydicom>=2.2.0
#   Downloading pydicom-2.4.4-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 17.8 MB/s eta 0:00:00:00:01
# Collecting nibabel
#   Downloading nibabel-5.2.0-py3-none-any.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 40.7 MB/s eta 0:00:00:00:01
# Collecting python-gdcm
#   Downloading python_gdcm-3.0.22-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 7.0 MB/s eta 0:00:0000:01:00:01
# Requirement already satisfied: packaging>=17 in /home/coder/.local/lib/python3.9/site-packages (from nibabel->dicom2nifti) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/coder/.local/lib/python3.9/site-packages (from packaging>=17->nibabel->dicom2nifti) (3.0.9)
# Installing collected packages: python-gdcm, pydicom, nibabel, dicom2nifti
# Successfully installed dicom2nifti-2.4.9 nibabel-5.2.0 pydicom-2.4.4 python-gdcm-3.0.22
#
# [notice] A new release of pip available: 22.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nibabel in /home/coder/.local/lib/python3.9/site-packages (5.2.0)
# Requirement already satisfied: numpy>=1.20 in /home/coder/.local/lib/python3.9/site-packages (from nibabel) (1.23.0)
# Requirement already satisfied: packaging>=17 in /home/coder/.local/lib/python3.9/site-packages (from nibabel) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/coder/.local/lib/python3.9/site-packages (from packaging>=17->nibabel) (3.0.9)
#
# [notice] A new release of pip available: 22.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nilearn
#   Downloading nilearn-0.10.2-py3-none-any.whl (10.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 20.4 MB/s eta 0:00:0000:010:01m
# Requirement already satisfied: joblib>=1.0.0 in /home/coder/.local/lib/python3.9/site-packages (from nilearn) (1.1.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /home/coder/.local/lib/python3.9/site-packages (from nilearn) (1.1.1)
# Requirement already satisfied: numpy>=1.19.0 in /home/coder/.local/lib/python3.9/site-packages (from nilearn) (1.23.0)
# Collecting lxml
#   Downloading lxml-4.9.3-cp39-cp39-manylinux_2_28_x86_64.whl (8.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 47.8 MB/s eta 0:00:00:00:01
# Requirement already satisfied: nibabel>=3.2.0 in /home/coder/.local/lib/python3.9/site-packages (from nilearn) (5.2.0)
# Requirement already satisfied: pandas>=1.1.5 in /home/coder/.local/lib/python3.9/site-packages (from nilearn) (1.4.3)
# Requirement already satisfied: packaging in /home/coder/.local/lib/python3.9/site-packages (from nilearn) (21.3)
# Requirement already satisfied: requests>=2.25.0 in /home/coder/.local/lib/python3.9/site-packages (from nilearn) (2.28.1)
# Requirement already satisfied: scipy>=1.6.0 in /home/coder/.local/lib/python3.9/site-packages (from nilearn) (1.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/coder/.local/lib/python3.9/site-packages (from packaging->nilearn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/coder/.local/lib/python3.9/site-packages (from pandas>=1.1.5->nilearn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/coder/.local/lib/python3.9/site-packages (from pandas>=1.1.5->nilearn) (2022.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/coder/.local/lib/python3.9/site-packages (from requests>=2.25.0->nilearn) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/coder/.local/lib/python3.9/site-packages (from requests>=2.25.0->nilearn) (1.26.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/coder/.local/lib/python3.9/site-packages (from requests>=2.25.0->nilearn) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/coder/.local/lib/python3.9/site-packages (from requests>=2.25.0->nilearn) (3.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/coder/.local/lib/python3.9/site-packages (from scikit-learn>=1.0.0->nilearn) (3.1.0)
# Requirement already satisfied: six>=1.5 in /home/coder/.local/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->nilearn) (1.16.0)
# Installing collected packages: lxml, nilearn
# Successfully installed lxml-4.9.3 nilearn-0.10.2
#
# [notice] A new release of pip available: 22.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/coder/.local/lib/python3.9/site-packages (1.1.1)
# Requirement already satisfied: joblib>=1.0.0 in /home/coder/.local/lib/python3.9/site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/coder/.local/lib/python3.9/site-packages (from scikit-learn) (1.23.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/coder/.local/lib/python3.9/site-packages (from scikit-learn) (1.8.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/coder/.local/lib/python3.9/site-packages (from scikit-learn) (3.1.0)
#
# [notice] A new release of pip available: 22.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mne
#   Downloading mne-1.6.0-py3-none-any.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 52.6 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: numpy>=1.21.2 in /home/coder/.local/lib/python3.9/site-packages (from mne) (1.23.0)
# Collecting pooch>=1.5
#   Downloading pooch-1.8.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: defusedxml in /home/coder/.local/lib/python3.9/site-packages (from mne) (0.7.1)
# Requirement already satisfied: matplotlib>=3.5.0 in /home/coder/.local/lib/python3.9/site-packages (from mne) (3.7.1)
# Requirement already satisfied: scipy>=1.7.1 in /home/coder/.local/lib/python3.9/site-packages (from mne) (1.8.1)
# Collecting lazy-loader>=0.3
#   Downloading lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: jinja2 in /home/coder/.local/lib/python3.9/site-packages (from mne) (3.1.2)
# Requirement already satisfied: tqdm in /home/coder/.local/lib/python3.9/site-packages (from mne) (4.64.0)
# Requirement already satisfied: decorator in /home/coder/.local/lib/python3.9/site-packages (from mne) (5.1.1)
# Requirement already satisfied: packaging in /home/coder/.local/lib/python3.9/site-packages (from mne) (21.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib>=3.5.0->mne) (6.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib>=3.5.0->mne) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib>=3.5.0->mne) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib>=3.5.0->mne) (4.34.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib>=3.5.0->mne) (1.4.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib>=3.5.0->mne) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib>=3.5.0->mne) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib>=3.5.0->mne) (3.0.9)
# Requirement already satisfied: requests>=2.19.0 in /home/coder/.local/lib/python3.9/site-packages (from pooch>=1.5->mne) (2.28.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/coder/.local/lib/python3.9/site-packages (from pooch>=1.5->mne) (2.5.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/coder/.local/lib/python3.9/site-packages (from jinja2->mne) (2.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/coder/.local/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.5.0->mne) (3.8.0)
# Requirement already satisfied: six>=1.5 in /home/coder/.local/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->mne) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/coder/.local/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/coder/.local/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/coder/.local/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/coder/.local/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (1.26.9)
# Installing collected packages: lazy-loader, pooch, mne
# Successfully installed lazy-loader-0.3 mne-1.6.0 pooch-1.8.0
#
# [notice] A new release of pip available: 22.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/coder/.local/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in /home/coder/.local/lib/python3.9/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: scipy>=1.0 in /home/coder/.local/lib/python3.9/site-packages (from seaborn) (1.8.1)
# Requirement already satisfied: pandas>=0.23 in /home/coder/.local/lib/python3.9/site-packages (from seaborn) (1.4.3)
# Requirement already satisfied: numpy>=1.15 in /home/coder/.local/lib/python3.9/site-packages (from seaborn) (1.23.0)
# Requirement already satisfied: packaging>=20.0 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.4.3)
# Requirement already satisfied: cycler>=0.10 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (6.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (4.34.1)
# Requirement already satisfied: pytz>=2020.1 in /home/coder/.local/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/coder/.local/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=2.2->seaborn) (3.8.0)
# Requirement already satisfied: six>=1.5 in /home/coder/.local/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
#
# [notice] A new release of pip available: 22.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting crtoolbox
#   Downloading crtoolbox-0.1.7-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /home/coder/.local/lib/python3.9/site-packages (from crtoolbox) (3.7.1)
# Requirement already satisfied: nbformat>=4.2.0 in /home/coder/.local/lib/python3.9/site-packages (from crtoolbox) (5.4.0)
# Requirement already satisfied: plotly in /home/coder/.local/lib/python3.9/site-packages (from crtoolbox) (5.9.0)
# Requirement already satisfied: pyyaml in /home/coder/.local/lib/python3.9/site-packages (from crtoolbox) (6.0)
# Requirement already satisfied: nibabel in /home/coder/.local/lib/python3.9/site-packages (from crtoolbox) (5.2.0)
# Requirement already satisfied: nilearn in /home/coder/.local/lib/python3.9/site-packages (from crtoolbox) (0.10.2)
# Requirement already satisfied: numpy in /home/coder/.local/lib/python3.9/site-packages (from crtoolbox) (1.23.0)
# Requirement already satisfied: pandas in /home/coder/.local/lib/python3.9/site-packages (from crtoolbox) (1.4.3)
# Requirement already satisfied: jupyter-core in /home/coder/.local/lib/python3.9/site-packages (from nbformat>=4.2.0->crtoolbox) (4.10.0)
# Requirement already satisfied: jsonschema>=2.6 in /home/coder/.local/lib/python3.9/site-packages (from nbformat>=4.2.0->crtoolbox) (4.6.1)
# Requirement already satisfied: fastjsonschema in /home/coder/.local/lib/python3.9/site-packages (from nbformat>=4.2.0->crtoolbox) (2.15.3)
# Requirement already satisfied: traitlets>=5.1 in /home/coder/.local/lib/python3.9/site-packages (from nbformat>=4.2.0->crtoolbox) (5.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib->crtoolbox) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib->crtoolbox) (1.4.3)
# Requirement already satisfied: packaging>=20.0 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib->crtoolbox) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib->crtoolbox) (4.34.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib->crtoolbox) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib->crtoolbox) (9.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib->crtoolbox) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib->crtoolbox) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib->crtoolbox) (6.1.1)
# Requirement already satisfied: lxml in /home/coder/.local/lib/python3.9/site-packages (from nilearn->crtoolbox) (4.9.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /home/coder/.local/lib/python3.9/site-packages (from nilearn->crtoolbox) (1.1.1)
# Requirement already satisfied: joblib>=1.0.0 in /home/coder/.local/lib/python3.9/site-packages (from nilearn->crtoolbox) (1.1.0)
# Requirement already satisfied: requests>=2.25.0 in /home/coder/.local/lib/python3.9/site-packages (from nilearn->crtoolbox) (2.28.1)
# Requirement already satisfied: scipy>=1.6.0 in /home/coder/.local/lib/python3.9/site-packages (from nilearn->crtoolbox) (1.8.1)
# Requirement already satisfied: pytz>=2020.1 in /home/coder/.local/lib/python3.9/site-packages (from pandas->crtoolbox) (2022.1)
# Requirement already satisfied: tenacity>=6.2.0 in /home/coder/.local/lib/python3.9/site-packages (from plotly->crtoolbox) (8.0.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/coder/.local/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->crtoolbox) (3.8.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/coder/.local/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->crtoolbox) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/coder/.local/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->crtoolbox) (21.4.0)
# Requirement already satisfied: six>=1.5 in /home/coder/.local/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->crtoolbox) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/coder/.local/lib/python3.9/site-packages (from requests>=2.25.0->nilearn->crtoolbox) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/coder/.local/lib/python3.9/site-packages (from requests>=2.25.0->nilearn->crtoolbox) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /home/coder/.local/lib/python3.9/site-packages (from requests>=2.25.0->nilearn->crtoolbox) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/coder/.local/lib/python3.9/site-packages (from requests>=2.25.0->nilearn->crtoolbox) (1.26.9)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/coder/.local/lib/python3.9/site-packages (from scikit-learn>=1.0.0->nilearn->crtoolbox) (3.1.0)
# Installing collected packages: crtoolbox
# Successfully installed crtoolbox-0.1.7
#
# [notice] A new release of pip available: 22.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipywidgets in /home/coder/.local/lib/python3.9/site-packages (7.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/coder/.local/lib/python3.9/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/coder/.local/lib/python3.9/site-packages (from ipywidgets) (6.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/coder/.local/lib/python3.9/site-packages (from ipywidgets) (5.3.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /home/coder/.local/lib/python3.9/site-packages (from ipywidgets) (3.6.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/coder/.local/lib/python3.9/site-packages (from ipywidgets) (1.1.1)
# Requirement already satisfied: ipython>=4.0.0 in /home/coder/.local/lib/python3.9/site-packages (from ipywidgets) (8.4.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/coder/.local/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: tornado>=6.1 in /home/coder/.local/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: packaging in /home/coder/.local/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (21.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/coder/.local/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.3.4)
# Requirement already satisfied: psutil in /home/coder/.local/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.1)
# Requirement already satisfied: debugpy>=1.0 in /home/coder/.local/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /home/coder/.local/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (23.2.0)
# Requirement already satisfied: nest-asyncio in /home/coder/.local/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.5)
# Requirement already satisfied: jedi>=0.16 in /home/coder/.local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: backcall in /home/coder/.local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pickleshare in /home/coder/.local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: stack-data in /home/coder/.local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.3.0)
# Requirement already satisfied: pexpect>4.3 in /home/coder/.local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: decorator in /home/coder/.local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /home/coder/.local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (2.12.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/coder/.local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (3.0.30)
# Requirement already satisfied: setuptools>=18.5 in /usr/lib/python3/dist-packages (from ipython>=4.0.0->ipywidgets) (52.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /home/coder/.local/lib/python3.9/site-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.4.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/coder/.local/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.9.2 in /home/coder/.local/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (4.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/coder/.local/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: entrypoints in /home/coder/.local/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: nbformat in /home/coder/.local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.4.0)
# Requirement already satisfied: argon2-cffi in /home/coder/.local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in /home/coder/.local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.5.0)
# Requirement already satisfied: prometheus-client in /home/coder/.local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.14.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/coder/.local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/coder/.local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.15.0)
# Requirement already satisfied: jinja2 in /home/coder/.local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/coder/.local/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/coder/.local/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/coder/.local/lib/python3.9/site-packages (from packaging->ipykernel>=4.5.1->ipywidgets) (3.0.9)
# Requirement already satisfied: pure-eval in /home/coder/.local/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens in /home/coder/.local/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
# Requirement already satisfied: executing in /home/coder/.local/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: defusedxml in /home/coder/.local/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/coder/.local/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/coder/.local/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in /home/coder/.local/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.6.6)
# Requirement already satisfied: beautifulsoup4 in /home/coder/.local/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in /home/coder/.local/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/coder/.local/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.1.1)
# Requirement already satisfied: bleach in /home/coder/.local/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.0.1)
# Requirement already satisfied: tinycss2 in /home/coder/.local/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.1.1)
# Requirement already satisfied: fastjsonschema in /home/coder/.local/lib/python3.9/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.15.3)
# Requirement already satisfied: jsonschema>=2.6 in /home/coder/.local/lib/python3.9/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.6.1)
# Requirement already satisfied: six>=1.5 in /home/coder/.local/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/coder/.local/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/coder/.local/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/coder/.local/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.18.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/coder/.local/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /home/coder/.local/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.3.2.post1)
# Requirement already satisfied: webencodings in /home/coder/.local/lib/python3.9/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pycparser in /home/coder/.local/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.21)
#
# [notice] A new release of pip available: 22.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/coder/.local/lib/python3.9/site-packages (1.4.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/coder/.local/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /home/coder/.local/lib/python3.9/site-packages (from pandas) (1.23.0)
# Requirement already satisfied: pytz>=2020.1 in /home/coder/.local/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in /home/coder/.local/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
#
# [notice] A new release of pip available: 22.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement itertools (from versions: none)
# ERROR: No matching distribution found for itertools
#
# [notice] A new release of pip available: 22.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ndslib
#   Downloading ndslib-0.6-py3-none-any.whl (15 kB)
# Requirement already satisfied: nilearn in /home/coder/.local/lib/python3.9/site-packages (from ndslib) (0.10.2)
# Collecting numpydoc
#   Downloading numpydoc-1.6.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /home/coder/.local/lib/python3.9/site-packages (from ndslib) (1.4.3)
# Collecting sphinx
#   Downloading sphinx-7.2.6-py3-none-any.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 34.7 MB/s eta 0:00:00:00:01
# Requirement already satisfied: seaborn in /home/coder/.local/lib/python3.9/site-packages (from ndslib) (0.11.2)
# Requirement already satisfied: jupyter in /home/coder/.local/lib/python3.9/site-packages (from ndslib) (1.0.0)
# Collecting sphinx-math-dollar
#   Downloading sphinx_math_dollar-1.2.1-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: numpy in /home/coder/.local/lib/python3.9/site-packages (from ndslib) (1.23.0)
# Collecting viznet
#   Downloading viznet-0.3.0-py2.py3-none-any.whl (23 kB)
# Collecting scikit-image
#   Downloading scikit_image-0.22.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 52.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: nibabel in /home/coder/.local/lib/python3.9/site-packages (from ndslib) (5.2.0)
# Requirement already satisfied: ipython in /home/coder/.local/lib/python3.9/site-packages (from ndslib) (8.4.0)
# Collecting sphinx-rtd-theme
#   Downloading sphinx_rtd_theme-2.0.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 42.7 MB/s eta 0:00:00:00:01
# Requirement already satisfied: matplotlib in /home/coder/.local/lib/python3.9/site-packages (from ndslib) (3.7.1)
# Collecting sphinx-copybutton
#   Downloading sphinx_copybutton-0.5.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: scikit-learn in /home/coder/.local/lib/python3.9/site-packages (from ndslib) (1.1.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/lib/python3/dist-packages (from ipython->ndslib) (52.0.0)
# Requirement already satisfied: decorator in /home/coder/.local/lib/python3.9/site-packages (from ipython->ndslib) (5.1.1)
# Requirement already satisfied: backcall in /home/coder/.local/lib/python3.9/site-packages (from ipython->ndslib) (0.2.0)
# Requirement already satisfied: pickleshare in /home/coder/.local/lib/python3.9/site-packages (from ipython->ndslib) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /home/coder/.local/lib/python3.9/site-packages (from ipython->ndslib) (0.1.3)
# Requirement already satisfied: stack-data in /home/coder/.local/lib/python3.9/site-packages (from ipython->ndslib) (0.3.0)
# Requirement already satisfied: pexpect>4.3 in /home/coder/.local/lib/python3.9/site-packages (from ipython->ndslib) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/coder/.local/lib/python3.9/site-packages (from ipython->ndslib) (3.0.30)
# Requirement already satisfied: pygments>=2.4.0 in /home/coder/.local/lib/python3.9/site-packages (from ipython->ndslib) (2.12.0)
# Requirement already satisfied: traitlets>=5 in /home/coder/.local/lib/python3.9/site-packages (from ipython->ndslib) (5.3.0)
# Requirement already satisfied: jedi>=0.16 in /home/coder/.local/lib/python3.9/site-packages (from ipython->ndslib) (0.18.1)
# Requirement already satisfied: qtconsole in /home/coder/.local/lib/python3.9/site-packages (from jupyter->ndslib) (5.3.1)
# Requirement already satisfied: ipykernel in /home/coder/.local/lib/python3.9/site-packages (from jupyter->ndslib) (6.15.0)
# Requirement already satisfied: ipywidgets in /home/coder/.local/lib/python3.9/site-packages (from jupyter->ndslib) (7.7.1)
# Requirement already satisfied: notebook in /home/coder/.local/lib/python3.9/site-packages (from jupyter->ndslib) (6.4.12)
# Requirement already satisfied: jupyter-console in /home/coder/.local/lib/python3.9/site-packages (from jupyter->ndslib) (6.4.4)
# Requirement already satisfied: nbconvert in /home/coder/.local/lib/python3.9/site-packages (from jupyter->ndslib) (6.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib->ndslib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib->ndslib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib->ndslib) (1.4.3)
# Requirement already satisfied: packaging>=20.0 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib->ndslib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib->ndslib) (9.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib->ndslib) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib->ndslib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib->ndslib) (6.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib->ndslib) (4.34.1)
# Requirement already satisfied: requests>=2.25.0 in /home/coder/.local/lib/python3.9/site-packages (from nilearn->ndslib) (2.28.1)
# Requirement already satisfied: lxml in /home/coder/.local/lib/python3.9/site-packages (from nilearn->ndslib) (4.9.3)
# Requirement already satisfied: joblib>=1.0.0 in /home/coder/.local/lib/python3.9/site-packages (from nilearn->ndslib) (1.1.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/coder/.local/lib/python3.9/site-packages (from nilearn->ndslib) (1.8.1)
# Requirement already satisfied: pytz>=2020.1 in /home/coder/.local/lib/python3.9/site-packages (from pandas->ndslib) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/coder/.local/lib/python3.9/site-packages (from scikit-learn->ndslib) (3.1.0)
# Requirement already satisfied: tomli>=1.1.0 in /home/coder/.local/lib/python3.9/site-packages (from numpydoc->ndslib) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10 in /home/coder/.local/lib/python3.9/site-packages (from numpydoc->ndslib) (3.1.2)
# Collecting tabulate>=0.8.10
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.7-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 4.2 MB/s eta 0:00:00
# Collecting imagesize>=1.3
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Collecting snowballstemmer>=2.0
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 3.2 MB/s eta 0:00:00
# Collecting babel>=2.9
#   Downloading Babel-2.14.0-py3-none-any.whl (11.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 61.5 MB/s eta 0:00:0000:0100:01
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.6-py3-none-any.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.4/89.4 kB 4.5 MB/s eta 0:00:00
# Collecting docutils<0.21,>=0.18.1
#   Downloading docutils-0.20.1-py3-none-any.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.7/572.7 kB 30.6 MB/s eta 0:00:00
# Collecting pygments>=2.4.0
#   Downloading pygments-2.17.2-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.8 MB/s eta 0:00:00:00:01
# Requirement already satisfied: importlib-metadata>=4.8 in /home/coder/.local/lib/python3.9/site-packages (from sphinx->ndslib) (4.12.0)
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Downloading sphinxcontrib_htmlhelp-2.0.4-py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 3.9 MB/s eta 0:00:00
# Collecting alabaster<0.8,>=0.7
#   Downloading alabaster-0.7.13-py3-none-any.whl (13 kB)
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.5-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.5/83.5 kB 3.8 MB/s eta 0:00:00
# Collecting sphinxcontrib-serializinghtml>=1.1.9
#   Downloading sphinxcontrib_serializinghtml-1.1.9-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.7/92.7 kB 1.8 MB/s eta 0:00:00:00:01
# Collecting tifffile>=2022.8.12
#   Downloading tifffile-2023.12.9-py3-none-any.whl (223 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.6/223.6 kB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=2.8 in /home/coder/.local/lib/python3.9/site-packages (from scikit-image->ndslib) (2.8.4)
# Requirement already satisfied: lazy_loader>=0.3 in /home/coder/.local/lib/python3.9/site-packages (from scikit-image->ndslib) (0.3)
# Requirement already satisfied: imageio>=2.27 in /home/coder/.local/lib/python3.9/site-packages (from scikit-image->ndslib) (2.33.1)
# Collecting sphinxcontrib-jquery<5,>=4
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /home/coder/.local/lib/python3.9/site-packages (from importlib-metadata>=4.8->sphinx->ndslib) (3.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/coder/.local/lib/python3.9/site-packages (from jedi>=0.16->ipython->ndslib) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/coder/.local/lib/python3.9/site-packages (from Jinja2>=2.10->numpydoc->ndslib) (2.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/coder/.local/lib/python3.9/site-packages (from pexpect>4.3->ipython->ndslib) (0.7.0)
# Requirement already satisfied: wcwidth in /home/coder/.local/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ndslib) (0.2.5)
# Requirement already satisfied: six>=1.5 in /home/coder/.local/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->ndslib) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/coder/.local/lib/python3.9/site-packages (from requests>=2.25.0->nilearn->ndslib) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/coder/.local/lib/python3.9/site-packages (from requests>=2.25.0->nilearn->ndslib) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/coder/.local/lib/python3.9/site-packages (from requests>=2.25.0->nilearn->ndslib) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/coder/.local/lib/python3.9/site-packages (from requests>=2.25.0->nilearn->ndslib) (2.1.0)
# Requirement already satisfied: nest-asyncio in /home/coder/.local/lib/python3.9/site-packages (from ipykernel->jupyter->ndslib) (1.5.5)
# Requirement already satisfied: psutil in /home/coder/.local/lib/python3.9/site-packages (from ipykernel->jupyter->ndslib) (5.9.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/coder/.local/lib/python3.9/site-packages (from ipykernel->jupyter->ndslib) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in /home/coder/.local/lib/python3.9/site-packages (from ipykernel->jupyter->ndslib) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /home/coder/.local/lib/python3.9/site-packages (from ipykernel->jupyter->ndslib) (6.2)
# Requirement already satisfied: debugpy>=1.0 in /home/coder/.local/lib/python3.9/site-packages (from ipykernel->jupyter->ndslib) (1.6.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/coder/.local/lib/python3.9/site-packages (from ipywidgets->jupyter->ndslib) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/coder/.local/lib/python3.9/site-packages (from ipywidgets->jupyter->ndslib) (1.1.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /home/coder/.local/lib/python3.9/site-packages (from ipywidgets->jupyter->ndslib) (3.6.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/coder/.local/lib/python3.9/site-packages (from nbconvert->jupyter->ndslib) (0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /home/coder/.local/lib/python3.9/site-packages (from nbconvert->jupyter->ndslib) (0.6.6)
# Requirement already satisfied: nbformat>=5.1 in /home/coder/.local/lib/python3.9/site-packages (from nbconvert->jupyter->ndslib) (5.4.0)
# Requirement already satisfied: bleach in /home/coder/.local/lib/python3.9/site-packages (from nbconvert->jupyter->ndslib) (5.0.1)
# Requirement already satisfied: tinycss2 in /home/coder/.local/lib/python3.9/site-packages (from nbconvert->jupyter->ndslib) (1.1.1)
# Requirement already satisfied: beautifulsoup4 in /home/coder/.local/lib/python3.9/site-packages (from nbconvert->jupyter->ndslib) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/coder/.local/lib/python3.9/site-packages (from nbconvert->jupyter->ndslib) (1.5.0)
# Requirement already satisfied: defusedxml in /home/coder/.local/lib/python3.9/site-packages (from nbconvert->jupyter->ndslib) (0.7.1)
# Requirement already satisfied: jupyter-core>=4.7 in /home/coder/.local/lib/python3.9/site-packages (from nbconvert->jupyter->ndslib) (4.10.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/coder/.local/lib/python3.9/site-packages (from nbconvert->jupyter->ndslib) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /home/coder/.local/lib/python3.9/site-packages (from nbconvert->jupyter->ndslib) (0.2.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/coder/.local/lib/python3.9/site-packages (from notebook->jupyter->ndslib) (0.15.0)
# Requirement already satisfied: prometheus-client in /home/coder/.local/lib/python3.9/site-packages (from notebook->jupyter->ndslib) (0.14.1)
# Requirement already satisfied: argon2-cffi in /home/coder/.local/lib/python3.9/site-packages (from notebook->jupyter->ndslib) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/coder/.local/lib/python3.9/site-packages (from notebook->jupyter->ndslib) (1.8.0)
# Requirement already satisfied: qtpy>=2.0.1 in /home/coder/.local/lib/python3.9/site-packages (from qtconsole->jupyter->ndslib) (2.1.0)
# Requirement already satisfied: asttokens in /home/coder/.local/lib/python3.9/site-packages (from stack-data->ipython->ndslib) (2.0.5)
# Requirement already satisfied: pure-eval in /home/coder/.local/lib/python3.9/site-packages (from stack-data->ipython->ndslib) (0.2.2)
# Requirement already satisfied: executing in /home/coder/.local/lib/python3.9/site-packages (from stack-data->ipython->ndslib) (0.8.3)
# Requirement already satisfied: jsonschema>=2.6 in /home/coder/.local/lib/python3.9/site-packages (from nbformat>=5.1->nbconvert->jupyter->ndslib) (4.6.1)
# Requirement already satisfied: fastjsonschema in /home/coder/.local/lib/python3.9/site-packages (from nbformat>=5.1->nbconvert->jupyter->ndslib) (2.15.3)
# Requirement already satisfied: argon2-cffi-bindings in /home/coder/.local/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter->ndslib) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /home/coder/.local/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter->ndslib) (2.3.2.post1)
# Requirement already satisfied: webencodings in /home/coder/.local/lib/python3.9/site-packages (from bleach->nbconvert->jupyter->ndslib) (0.5.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/coder/.local/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->ndslib) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/coder/.local/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->ndslib) (0.18.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/coder/.local/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->ndslib) (1.15.1)
# Requirement already satisfied: pycparser in /home/coder/.local/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->ndslib) (2.21)
# Installing collected packages: snowballstemmer, tifffile, tabulate, sphinxcontrib-jsmath, pygments, imagesize, docutils, babel, alabaster, scikit-image, viznet, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, sphinx, sphinxcontrib-jquery, sphinx-rtd-theme, sphinx-math-dollar, sphinx-copybutton, numpydoc, ndslib
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.12.0
#     Uninstalling Pygments-2.12.0:
#       Successfully uninstalled Pygments-2.12.0
# Successfully installed alabaster-0.7.13 babel-2.14.0 docutils-0.20.1 imagesize-1.4.1 ndslib-0.6 numpydoc-1.6.0 pygments-2.17.2 scikit-image-0.22.0 snowballstemmer-2.2.0 sphinx-7.2.6 sphinx-copybutton-0.5.2 sphinx-math-dollar-1.2.1 sphinx-rtd-theme-2.0.0 sphinxcontrib-applehelp-1.0.7 sphinxcontrib-devhelp-1.0.5 sphinxcontrib-htmlhelp-2.0.4 sphinxcontrib-jquery-4.1 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.6 sphinxcontrib-serializinghtml-1.1.9 tabulate-0.9.0 tifffile-2023.12.9 viznet-0.3.0
#
# [notice] A new release of pip available: 22.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
#
# [notice] A new release of pip available: 22.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Done!

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Check that we are in the right environment
#
# </div>

# %%
import sys
print(sys.executable)
#Check that we have something installed.
import nilearn
# Out:
# /usr/bin/python3

# %%
# Additional imports
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pickle
import pandas as pd
import nilearn
import sklearn

# %% [markdown]
# ### Let's load the faceWord searchlight data from one participant

# %%
import pickle

now = datetime.now()
print('Starting cell:',now.strftime("%H:%M:%S"))

f = open('/work/fMRI_data/FaceWordData/WordFace_searchlight_1.pkl', 'rb')
searchlight = pickle.load(f)
f.close()
print(searchlight)

now = datetime.now()
print('Finishing cell:',now.strftime("%H:%M:%S"))
# Out:
# Starting cell: 20:17:18
# SearchLight(cv=10, estimator=LinearSVC(dual='auto', max_iter=2000),
#             mask_img=<nibabel.nifti1.Nifti1Image object at 0x7fae40315220>,
#             n_jobs=-1,
#             process_mask_img=<nibabel.nifti1.Nifti1Image object at 0x7fae397dae20>,
#             radius=5, verbose=10)
# Finishing cell: 20:17:18
# /home/coder/.local/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator LinearSVC from version 1.3.0 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %% [markdown]
# ### Plotting searchlight from one participant

# %%
from nilearn.plotting import plot_glass_brain, plot_stat_map
from nilearn.image import new_img_like
import numpy as np

from nilearn import plotting
import matplotlib.pyplot as plt
mask_wb_filename='/work/fMRI_data/FaceWordData/BIDS/derivatives/sub-0054/anat/sub-0054_acq-T1sequence_run-1_space-MNI152NLin2009cAsym_desc-brain_mask.nii.gz'

now = datetime.now()
print('Starting cell:',now.strftime("%H:%M:%S"))

searchlight_img = new_img_like(mask_wb_filename, searchlight.scores_)
print(searchlight_img.shape)


plot_glass_brain(searchlight_img, cmap='jet',colorbar=True, threshold=0.6,
                              title=('sub1'),
                              plot_abs=False, display_mode='x')

   
#plt.suptitle('Classification accuracy (unc Acc>0.6)')
plt.show()

plot_stat_map(searchlight_img, cmap='cold_hot',threshold=0.5, cut_coords=[-30,-20,-10,0,10,20,30],
              display_mode='z',  black_bg=False,
              title='[image_neg-image_pos] accuracy')
plt.show()

# Saving the objects:
#f = open('/work/MikkelWallentin#6287/WordFace_first_level_models_all_trials_searchlight_all_par.pkl', 'wb')
#pickle.dump([searchlight_all, searchlight_img], f)
#f.close()

now = datetime.now()
print('Finishing cell:',now.strftime("%H:%M:%S"))
# Out:
# Starting cell: 20:17:22
# (193, 235, 198)
# Finishing cell: 20:17:27

# %% [markdown]
# ## Load searchlight maps for each participant

# %%
from nilearn.image import new_img_like, math_img
N_par=21
searchlight_all= np.empty((N_par, 0)).tolist()
searchlight_all=[]
searchlight_demean=[]
conditions_label_all= np.empty((N_par, 0)).tolist()
for i in range(0,N_par):
    text = "Loading file %d\n" % (i+1)
    print(text)
    file_name='/work/fMRI_data/FaceWordData/WordFace_searchlight_'+str(i)+'.pkl'
    f = open(file_name, 'rb')
    searchlight = pickle.load(f)
    searchlight_img = new_img_like(mask_wb_filename, searchlight.scores_)
    searchlight_all.append(searchlight_img)
    searchlight_demean.append(math_img("(img1-0.5)*img2",img1=searchlight_img,img2=mask_wb_filename))
    
    #searchlight_all[i]=searchlight
    f.close()


print(searchlight_all[1])
            
now = datetime.now()
print('Finishing cell:',now.strftime("%H:%M:%S"))
# Out:
# Loading file 1
# /home/coder/.local/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator LinearSVC from version 1.3.0 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Loading file 2
#
# Loading file 3
#
# Loading file 4
#
# Loading file 5
#
# Loading file 6
#
# Loading file 7
#
# Loading file 8
#
# Loading file 9
#
# Loading file 10
#
# Loading file 11
#
# Loading file 12
#
# Loading file 13
#
# Loading file 14
#
# Loading file 15
#
# Loading file 16
#
# Loading file 17
#
# Loading file 18
#
# Loading file 19
#
# Loading file 20
#
# Loading file 21
#
#
# <class 'nibabel.nifti1.Nifti1Image'>
# data shape (193, 235, 198)
# affine:
# [[   1.       0.       0.     -96.   ]
#  [   0.       0.977    0.    -132.   ]
#  [   0.       0.       0.977  -78.   ]
#  [   0.       0.       0.       1.   ]]
# metadata:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b''
# dim_info        : 0
# dim             : [  3 193 235 198   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float64
# bitpix          : 64
# slice_start     : 0
# pixdim          : [1.    1.    0.977 0.977 1.    1.    1.    1.   ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 0
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b''
# aux_file        : b''
# qform_code      : unknown
# sform_code      : aligned
# quatern_b       : 0.0
# quatern_c       : 0.0
# quatern_d       : 0.0
# qoffset_x       : -96.0
# qoffset_y       : -132.0
# qoffset_z       : -78.0
# srow_x          : [  1.   0.   0. -96.]
# srow_y          : [   0.       0.977    0.    -132.   ]
# srow_z          : [  0.      0.      0.977 -78.   ]
# intent_name     : b''
# magic           : b'n+1'
#
# Finishing cell: 20:17:40

# %%
import matplotlib.pyplot as plt

from nilearn import plotting

#subjects = data["ext_vars"]["participant_id"].tolist()
fig, axes = plt.subplots(nrows=5, ncols=5)
for cidx, map in enumerate(searchlight_all):
    plotting.plot_glass_brain(
        map,
        colorbar=True,
        threshold=0.6,
        vmin=0.5,
        vmax=1,
        title=None,
        axes=axes[int(cidx / 5), int(cidx % 5)],
        plot_abs=False,
        display_mode="x",
    )
plt.show()

# %%
from nilearn.image import new_img_like,  mean_img, concat_imgs

#Concatenate beta maps
searchlight_conc=concat_imgs(searchlight_all)
# Make a mean image
searchlight_mean=mean_img(searchlight_conc)
#Concatenate baseline corrected maps
searchlight_conc_de=concat_imgs(searchlight_demean)
# Make a mean of the baseline-corrected image
searchlight_mean_demean=mean_img(searchlight_conc_de)

plot_glass_brain(searchlight_mean, cmap='jet',colorbar=True, threshold=0.55,
                              title=('Searchlight: Mean accuracy'),
                              plot_abs=False, display_mode='x')

plot_glass_brain(searchlight_mean_demean, cmap='jet',colorbar=True, threshold=0.05,vmin=0,
                              title=('Searchlight: Baseline corrected accuracy'),
                              plot_abs=False, display_mode='x')


plot_stat_map(searchlight_mean, cmap='jet',threshold=0.55, cut_coords=[-20,-10,0,10,20,30,40],
              display_mode='z',  black_bg=False,
              title='Group [image_neg-image_pos] accuracy')
plt.show()
plot_stat_map(searchlight_mean_demean, cmap='jet',threshold=0.05, cut_coords=[-20,-10,0,10,20,30,40],
              display_mode='z',  black_bg=False,
              title='Group [image_neg-image_pos] accuracy')
plt.show()

# %%
from nilearn.glm.second_level import SecondLevelModel
import pandas as pd

second_level_input = searchlight_demean
design_matrix = pd.DataFrame(
    [1] * len(second_level_input),
    columns=["intercept"],
)

second_level_model = SecondLevelModel(smoothing_fwhm=6.0, n_jobs=2)
second_level_model = second_level_model.fit(
    second_level_input,
    design_matrix=design_matrix,
)

z_map = second_level_model.compute_contrast(
    second_level_contrast="intercept",
    output_type="z_score",
)
# Out:
# /home/coder/.local/lib/python3.9/site-packages/nilearn/glm/_utils.py:346: RuntimeWarning: divide by zero encountered in divide
#   return np.where(X <= 0, 0, 1.0 / X)

# %%
from scipy.stats import norm
from nilearn.image import threshold_img
from nilearn.glm import threshold_stats_img

p_val = 0.001
p001_unc = norm.isf(p_val)
print(f"The p<0.001 threshold is {p001_unc:.3g}")

thresholded_map2, threshold2 = threshold_stats_img(
    z_map, alpha=0.05, height_control="fdr"
)
print(f"The FDR=.05 threshold is {threshold2:.3g}")

thresholded_map3, threshold3 = threshold_stats_img(
    z_map, alpha=0.05, height_control="bonferroni"
)
print(f"The p<.05 Bonferroni-corrected threshold is {threshold3:.3g}")

#Remove negative effects from image (they are meaningless)
z_map_disp=threshold_img(
    z_map,
    threshold=0,
    two_sided=False,
)



display = plotting.plot_glass_brain(
    z_map_disp,
    threshold=4,
    vmin=0,
    vmax=12,
    colorbar=True,
    symmetric_cbar=False,
    #display_mode="x",
    plot_abs=False,
    title="pos vs neg face (p<0.001, uncor)",
    figure=plt.figure(figsize=(5, 5)),
)
plotting.show()

display = plotting.plot_glass_brain(
    z_map_disp,
    threshold=threshold2,
    vmin=0,
    vmax=12,
    colorbar=True,
    symmetric_cbar=False,
    #display_mode="x",
    plot_abs=False,
    title="pos vs neg face (p<0.05, FDR)",
    figure=plt.figure(figsize=(5, 5)),
)
plotting.show()

display = plotting.plot_glass_brain(
    z_map_disp,
    threshold=threshold3,
    vmin=0,
    vmax=12,
    colorbar=True,
    symmetric_cbar=False,
    #display_mode="x",
    plot_abs=False,
    title="pos vs neg face (p<0.05, bonf)",
    figure=plt.figure(figsize=(5, 5)),
)
plotting.show()
# Out:
# The p<0.001 threshold is 3.09
# The FDR=.05 threshold is 2.61
# The p<.05 Bonferroni-corrected threshold is 5.57

# %% [markdown]
# Fancy plot

# %%
display = plotting.plot_glass_brain(
    z_map_disp,
    threshold=threshold3,
    vmin=0,
    vmax=12,
    colorbar=True,
    symmetric_cbar=False,
    cmap='cool',  # new colormap
    display_mode='lyrz',  # Changed display mode
    title="Positive vs Negative Face Activation \n(p<0.05, Bonferroni)", #title in 2 lines
    figure=plt.figure(figsize=(5, 5)), 
)
plotting.show()

# %% [markdown]
# Code for answering task c): Use the thresholded image and make a table of the significant regions (e.g. using atlasreader - see notebook 14)

# %%
import atlasreader
from atlasreader import create_output

create_output(z_map_disp, voxel_thresh=threshold3, cluster_extent=0,direction='both')
#Atlasreader automatically saves results to both .png-files and a csv-file. Look in your working directory.
pd.read_csv('atlasreader_peaks.csv')
# Out:
#    cluster_id  peak_x  peak_y  peak_z  peak_value   volume_mm  \
# 0           1      17 -96.828   9.930     6.59859  3629.12000
# 1           2     -11 -99.759   3.091     7.22111  2772.91000
# 2           3      16 -86.081 -12.541     6.45867   653.85200
# 3           4     -21 -96.828 -10.587     5.87094    99.27100
# 4           5     -22 -92.920 -16.449     5.63760     5.72717
#
#                aal             desikan_killiany  \
# 0         Cuneus_R  Right-Cerebral-White-Matter
# 1  Occipital_Sup_L      ctx-lh-lateraloccipital
# 2        Lingual_R               ctx-rh-lingual
# 3  Occipital_Inf_L   Left-Cerebral-White-Matter
# 4        Lingual_L   Left-Cerebral-White-Matter
#
#                                       harvard_oxford
# 0                         62.0% Right_Occipital_Pole
# 1                          54.0% Left_Occipital_Pole
# 2  39.0% Right_Occipital_Fusiform_Gyrus; 17.0% Ri...
# 3  53.0% Left_Occipital_Pole; 5.0% Left_Lateral_O...
# 4  41.0% Left_Occipital_Pole; 18.0% Left_Occipita...

# %% [markdown]
# ## Tasks and questions for assignment 5
# a) Make a short description of the methods used in the searchlight and group analyses.
#
# b) Consider the different thresholds. Pick one and try to argue for your choice.
#
# c) Use the thresholded image and make a table of the significant regions (e.g. using atlasreader - see notebook 14)
#
# d) Briefly describe the results and discuss the extent to which they are surprising, given the task of observing two emojis and responding with a buttonpress.
#
# e) Include at least one fancy plot.
#
# f) Eye-ball the univariate group analysis of the same data conducted in notebook 14. What is the difference, if any? Does the multivariate analysis tell us something we didn't already know+
#
# g) Smoothing has been applied to the 2nd level analysis. Briefly consider whether this is a good or bad thing, given that multvariate pattern analysis is based on the idea of patterns across voxels (you can also try changing the smoothing level).
#
# h) The t-test approach for group analyses of searchlight analyses has been widely used, but has also been heavily critized (e.g. see Allefeld 2016; Wang et al. 2020). Briefly consider what we could/should have done, if we had had more time.
#
# Individual assignment. Max. 2 pages, excl. figures and references, code as appendix.
#
# #### References
# Allefeld, C., Görgen, K., & Haynes, J.-D. (2016). Valid population inference for information-based imaging: From the second-level t-test to prevalence inference. Neuroimage, 141, 378-392, https://doi.org/10.1016/j.neuroimage.2016.07.040.
#
# Wang, Q., Cagna, B., Chaminade, T., & Takerkart, S. (2020). Inter-subject pattern analysis: A straightforward and powerful scheme for group-level MVPA. Neuroimage, 204, 116205, https://doi.org/10.1016/j.neuroimage.2019.116205.
